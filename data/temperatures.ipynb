# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #  Apamea

# %%
print(*np.logspace(-2, 2, 100), sep=", ")
# Out:
# 0.01, 0.010974987654930561, 0.012045035402587823, 0.013219411484660288, 0.014508287784959394, 0.015922827933410922, 0.01747528400007684, 0.019179102616724886, 0.02104904144512021, 0.023101297000831605, 0.025353644939701114, 0.027825594022071243, 0.030538555088334154, 0.033516026509388425, 0.03678379771828634, 0.040370172585965536, 0.044306214575838825, 0.04862601580065353, 0.0533669923120631, 0.05857020818056667, 0.06428073117284322, 0.07054802310718646, 0.0774263682681127, 0.08497534359086446, 0.093260334688322, 0.10235310218990264, 0.11233240329780277, 0.12328467394420665, 0.13530477745798075, 0.1484968262254465, 0.16297508346206444, 0.1788649529057435, 0.19630406500402714, 0.21544346900318845, 0.23644894126454083, 0.25950242113997374, 0.2848035868435802, 0.3125715849688237, 0.34304692863149194, 0.37649358067924693, 0.41320124001153385, 0.4534878508128584, 0.49770235643321115, 0.5462277217684343, 0.5994842503189411, 0.6579332246575682, 0.7220809018385468, 0.7924828983539177, 0.8697
# ...

# %%
a = np.loadtxt("apamea_N1280.out")
a = a[np.argsort(a[:,0])]
plt.figure(dpi=200)
plt.xscale("log")
plt.scatter(a[:,0], a[:,1])
plt.scatter(a[10:18,0], a[10:18,1])
plt.scatter(a[25:37,0], a[25:37,1])
temps = [1.2, 1.88, 2.5, 4.5, 8]
for t in temps:
    plt.axvline(t, c='red')

# %%
1.2, 1.88, 2.5, 4.5, 8
'sbatch -p common -N 1 -o "apamea/apamea_N1280.out" --exclusive -J "n0" start.sh apamea/apamea_N1280.ini -f apamea/apamea_N1280.mfsys --save 1000'
# Out:
# 'sbatch -p common -N 1 -o "apamea/apamea_N1280.out" --exclusive -J "n0" start.sh apamea/apamea_N1280.ini -f apamea/apamea_N1280.mfsys --save 1000'

# %% [markdown]
# # Cairo

# %%
a = np.loadtxt("cairo_N1280.out")
a = a[np.argsort(a[:,0])]
plt.figure(dpi=200)
plt.xscale("log")
plt.scatter(a[:,0], a[:,1])
plt.scatter(a[10:18,0], a[10:18,1])
plt.scatter(a[25:37,0], a[25:37,1])
temps = [5e-2, 1e-1, 5e-1, 4.1, 40]
for t in temps:
    plt.axvline(t, c='red')

print(*np.logspace(-2, 2, 50), sep=", ")
# Out:
# 0.01, 0.012067926406393288, 0.014563484775012436, 0.017575106248547922, 0.021209508879201904, 0.025595479226995357, 0.030888435964774818, 0.0372759372031494, 0.04498432668969444, 0.054286754393238594, 0.0655128556859551, 0.07906043210907697, 0.09540954763499938, 0.1151395399326447, 0.13894954943731375, 0.16768329368110074, 0.20235896477251566, 0.2442053094548651, 0.29470517025518095, 0.35564803062231287, 0.42919342601287763, 0.517947467923121, 0.6250551925273969, 0.7543120063354615, 0.9102981779915218, 1.0985411419875584, 1.325711365590108, 1.5998587196060574, 1.9306977288832496, 2.329951810515372, 2.811768697974228, 3.3932217718953264, 4.094915062380423, 4.941713361323833, 5.963623316594643, 7.196856730011514, 8.68511373751352, 10.481131341546853, 12.648552168552959, 15.264179671752318, 18.420699693267146, 22.229964825261934, 26.826957952797247, 32.374575428176435, 39.06939937054613, 47.1486636345739, 56.89866029018293, 68.66488450042998, 82.86427728546842, 100.0

# %%
print('sbatch -p common -N 1 -o "cairo/cairo_N1280.out" --exclusive -J "n0" start.sh cairo/cairo_N1280.ini -f cairo/cairo_N1280.mfsys --save 10')
# Out:
# sbatch -p common -N 1 -o "cairo/cairo_N1280.out" --exclusive -J "n0" start.sh cairo/cairo_N1280.ini -f cairo/cairo_N1280.mfsys --save 10

# %% [markdown]
# # Cyrrhus

# %%
a = np.loadtxt("cyrrhus_N1536.out")
plt.xscale("log")
plt.scatter(a[:,0], a[:,1])
temps = [1e-1, 6.5e-1, 4]
for t in temps:
    plt.axvline(t, c='red')

# %% [markdown]
# # 2D square ice
#
# ![image-2.png](attachment:image-2.png)

# %%
a = np.loadtxt("2d_square_N1152.out")
plt.xscale("log")
plt.scatter(a[:,0], a[:,1])
# temps = [1e-1, 6.5e-1, 4]
# for t in temps:
#     plt.axvline(t, c='red')

# %% [markdown]
# # 3D кубик (ДВМЖ)

# %%
a = np.loadtxt("3d_cube_N1536.out")
plt.xscale("log")
plt.scatter(a[:,0], a[:,1])
temps = [1e-1, 6.5e-1, 4]
for t in temps:
    plt.axvline(t, c='red')

# %% [markdown]
# # 2D Kagome (гексагональная)

# %%
a = np.loadtxt("2d_kagome_N1200.out")
a = a[np.argsort(a[:,0])]
plt.figure(dpi=200)
plt.xscale("log")
plt.scatter(a[:,0], a[:,1])
plt.scatter(a[8:20,0], a[8:20,1])
plt.scatter(a[34:44,0], a[34:44,1])
temps = [1e-1, 6.5e-1, 4]
for t in temps:
    plt.axvline(t, c='red')

# %% [markdown]
# ## Пересчитать в 0 радиусе

# %% [markdown]
# # 3D Kagome (та, что есть)

# %%
a = np.loadtxt("3d_kagome_N1080.out")
plt.xscale("log")
plt.scatter(a[:,0], a[:,1])
temps = [1e-1, 6.5e-1, 4]
for t in temps:
    plt.axvline(t, c='red')

# %% [markdown]
# ### 27.10.2025
#
# Результаты и планы на будущее
#
# У меня посчитаны точки автокорреляций для 4 систем
